# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 1. Matplotlib 그래프

# %% [markdown]
# ### Line plot

# %%
fig, ax = plt.subplots()
x = np.arange(15)
y = x**2
ax.plot(
    x, y,
    linestyle = ':',
    marker = '*',
    color = '#524FA1'
)

# %% [markdown]
# ### Line style

# %%
x = np.arange(10)
fig, ax = plt.subplots()

# solid
ax.plot(x, x, linestyle = '-')

# dashed
ax.plot(x, x + 2, linestyle = '--')

# dashdot
ax.plot(x, x + 4, linestyle = '-.')

# dotted
ax.plot(x, x + 6, linestyle = ':')

# %% [markdown]
# ### Color

# %%
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x, x, color = 'r')
ax.plot(x, x + 2, color = 'green')
ax.plot(x, x + 4, color = '0.8')
ax.plot(x, x + 6, color = '#524FA1')

# %% [markdown]
# ### Marker

# %%
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x, x, marker = '.')
ax.plot(x, x + 2, marker = 'o')
ax.plot(x, x + 4, marker = 'v')
ax.plot(x, x + 6, marker = 's')
ax.plot(x, x + 8, marker = '*')

# %% [markdown]
# ### 축 경계 조정하기

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))
ax.set_xlim(-2, 12)
ax.set_ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ### 범례

# %%
x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(x, x, label = 'y = x')
ax.plot(x, x**2, label = 'y = x^2')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(loc = 'upper right',
         shadow = True,
         fancybox = True,
         borderpad = 1)

# %% [markdown]
# ## 2. Bar & Histogram

# %% [markdown]
# ### Bar plot

# %%
# bar
x = np.arange(10)
fig, ax = plt.subplots(figsize = (12, 4))
ax.bar(x, x*2)
# Out:
# <BarContainer object of 10 artists>

# %%
x = np.random.rand(3)
y = np.random.rand(3)
z = np.random.rand(3)

data = [x, y, z]

fig, ax = plt.subplots()
x_ax = np.arange(3)
for i in x_ax:
    ax.bar(x_ax, data[i],
          bottom = np.sum(data[:i], axis = 0))
    
    ax.set_xticks(x_ax)
    ax.set_xticklabels(['A', 'B', 'C'])

# %% [markdown]
# ### Histogram

# %%
fig, ax = plt.subplots()
data = np.random.randn(1000)
_ = ax.hist(data, bins = 50)

# %% [markdown]
# ## 3. Matplotlib with Pandas

# %% [markdown]
# ### Matplotlib with Pandas

# %%
df = pd.read_csv('./data/president_heights.csv')
fig, ax = plt.subplots()
ax.plot(df['order'], df['height(cm)'], label = 'height')
ax.set_xlabel('order')
ax.set_ylabel('height(cm)')
# Out:
# Text(0, 0.5, 'height(cm)')

# %%
df = pd.read_csv('./data/pokemon.csv')
df.columns
df.head()
# Out:
#    ID        Name Form  Type1   Type2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  NaN  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  NaN  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  NaN  Grass  Poison    525  80      82       83      100
# 3   4  Charmander  NaN   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon  NaN   Fire     NaN    405  58      64       58       80
#
#    Sp. Def  Speed  Generation
# 0       65     45           1
# 1       80     60           1
# 2      100     80           1
# 3       50     65           1
# 4       65     80           1

# %%
fire = df[(df['Type1']=='Fire') | ((df['Type2'])=='Fire')]
water = df[(df['Type1']=='Water') | ((df['Type2'])=='Water')]

fig, ax = plt.subplots()
ax.scatter(fire['Attack'], fire['Defense'], color = 'r', label = 'Fire', marker = '*', s = 50)
ax.scatter(water['Attack'], water['Defense'], color = 'b', label = 'Water', s = 25)
ax.set_xlabel('Attack')
ax.set_ylabel('Defense')
ax.legend(loc = 'upper right')

# %% [markdown]
# ### 실습 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    linestyle='-',
    marker='.',
    color='blue'
)
ax.plot(
    x, x**2, label='y=x^2',
    linestyle='-.',
    marker=',',
    color='red'
)

# %% [markdown]
# ### 실습2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    linestyle='-',
    marker='.',
    color='blue'
)
ax.plot(
    x, x**2, label='y=x^2',
    linestyle='-.',
    marker=',',
    color='red'
)
ax.set_xlabel("x")
ax.set_ylabel("y")

#이미 입력되어 있는 코드의 다양한 속성값들을 변경해 봅시다.
ax.legend(
    loc='center left',
    shadow=True,
    fancybox=True,
    borderpad=2
)

# %% [markdown]
# ### 실습3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# Data set
x = np.array(["축구", "야구", "농구", "배드민턴", "탁구"])
y = np.array([13, 10, 17, 8, 7])
z = np.random.randn(1000)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Bar 그래프
axes[0].bar(x, y)
# 히스토그램
_ = axes[1].hist(z, bins = 200)

# %% [markdown]
# ### 실습 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("./data/pokemon.csv")

# 공격 타입 Type 1, Type 2 중에 Fire 속성이 존재하는 데이터들만 추출해보세요.
fire = df[(df['Type1']=='Fire')|(df['Type2']=='Fire')]
# 공격 타입 Type 1, Type 2 중에 Water 속성이 존재하는 데이터들만 추출해보세요.
water = df[(df['Type1']=='Water')|(df['Type2']=='Water')]

fig, ax = plt.subplots()
# 왼쪽 표를 참고하여 아래 코드를 완성해보세요.
ax.scatter(fire['Attack'], fire['Defense'],
    marker='*', color='r', label='Fire', s=50)
ax.scatter(water['Attack'], water['Defense'],
    marker='.', color='b', label='Water', s=25)

ax.set_xlabel("Attack")
ax.set_ylabel("Defense")
ax.legend(loc="upper right")
