# %%
import FinanceDataReader as fdr

# %% [markdown]
# ### KOSPI상장종목 전체 가져오기

# %%
fdr.StockListing? # 도움말

# %%
fdr.StockListing?? # 소스보기

# %%
# KRX : KRX 종목 전체
# KOSPI : KOSPI 종목
# KOSDAQ : KOSDAQ 종목
# KONEX : KONEX 종목
# NASDAQ : 나스닥 종목
# NYSE : 뉴욕증권거래소 종목
# SP500 : S&P500 종목

# %%
df_kospi = fdr.StockListing("KOSPI")
df_kospi.shape
# Out:
# (5476, 10)

# %%
### KOSPI 상장종목 전체 가져오기
df_kospi.head()
# Out:
#    Symbol Market               Name           Sector             Industry  \
# 1  095570  KOSPI             AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2  006840  KOSPI              AK홀딩스           기타 금융업                 지주사업
# 6  152100  KOSPI        ARIRANG 200              NaN                  NaN
# 7  295820  KOSPI    ARIRANG 200동일가중              NaN                  NaN
# 8  253150  KOSPI  ARIRANG 200선물레버리지              NaN                  NaN
#
#   ListingDate SettleMonth     Representative                       HomePage  \
# 1  2015-08-21         12월                박대현         http://www.ajnet.co.kr
# 2  1999-08-11         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr
# 6         NaT         NaN                NaN                            NaN
# 7         NaT         NaN                NaN                            NaN
# 8         NaT         NaN                NaN                            NaN
#
#   Region
# 1  서울특별시
# 2  서울특별시
# 6    NaN
# 7    NaN
# 8    NaN

# %%
df_kospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5476 entries, 1 to 7138
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          5476 non-null   object
#  1   Market          5476 non-null   object
#  2   Name            5476 non-null   object
#  3   Sector          810 non-null    object
#  4   Industry        797 non-null    object
#  5   ListingDate     810 non-null    datetime64[ns]
#  6   SettleMonth     810 non-null    object
#  7   Representative  810 non-null    object
#  8   HomePage        781 non-null    object
#  9   Region          810 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 470.6+ KB

# %%
# 기술통계 값 요약
df_kospi.describe()
# Out:
# <ipython-input-7-6c966884c0fc>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_kospi.describe()
#         Symbol Market         Name  Sector Industry          ListingDate  \
# count     5476   5476         5476     810      797                  810
# unique    5476      1         5476     129      756                  642
# top     018500  KOSPI  KBGA62셀트리온콜  기타 금융업     지주회사  1996-07-03 00:00:00
# freq         1   5476            1      61       18                    8
# first      NaN    NaN          NaN     NaN      NaN  1956-03-03 00:00:00
# last       NaN    NaN          NaN     NaN      NaN  2021-07-16 00:00:00
#
#        SettleMonth Representative                   HomePage Region
# count          810            810                        781    810
# ...

# %%
df_kospi = df_kospi.dropna().reset_index() # NaN 값 있는 행 삭제
df_kospi = df_kospi.iloc[:, 1:] # 기존의 인덱스 컬럼 버리기
df_kospi
# Out:
#      Symbol Market     Name           Sector  \
# 0    095570  KOSPI   AJ네트웍스  산업용 기계 및 장비 임대업
# 1    006840  KOSPI    AK홀딩스           기타 금융업
# 2    027410  KOSPI      BGF           기타 금융업
# 3    282330  KOSPI   BGF리테일           종합 소매업
# 4    138930  KOSPI  BNK금융지주           기타 금융업
# ..      ...    ...      ...              ...
# 767  079980  KOSPI      휴비스         화학섬유 제조업
# 768  005010  KOSPI      휴스틸        1차 철강 제조업
# 769  069260  KOSPI      휴켐스      기타 화학제품 제조업
# 770  000540  KOSPI     흥국화재              보험업
# 771  003280  KOSPI     흥아해운           해상 운송업
#
#                                           Industry ListingDate SettleMonth  \
# 0                              렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 1                                             지주사업  1999-08-11         12월
# 2                                             지주회사  2014-05-19         12월
# 3                                          체인화 편의점  2017-12-08         12월
# ...

# %%
# 파일명에 오늘 날짜 지정하여 저장

import datetime

today = datetime.datetime.today().strftime("%Y_%m_%d")
today

df_kospi.to_csv(f"kospi_{today}.csv", index=False)

# %%
import pandas as pd
# CSV로 저장된 파일을 다시 DataFrame으로 읽어오기

pd.read_csv(f"kospi_{today}.csv")
# Out:
#      Symbol Market     Name           Sector  \
# 0     95570  KOSPI   AJ네트웍스  산업용 기계 및 장비 임대업
# 1      6840  KOSPI    AK홀딩스           기타 금융업
# 2     27410  KOSPI      BGF           기타 금융업
# 3    282330  KOSPI   BGF리테일           종합 소매업
# 4    138930  KOSPI  BNK금융지주           기타 금융업
# ..      ...    ...      ...              ...
# 767   79980  KOSPI      휴비스         화학섬유 제조업
# 768    5010  KOSPI      휴스틸        1차 철강 제조업
# 769   69260  KOSPI      휴켐스      기타 화학제품 제조업
# 770     540  KOSPI     흥국화재              보험업
# 771    3280  KOSPI     흥아해운           해상 운송업
#
#                                           Industry ListingDate SettleMonth  \
# 0                              렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 1                                             지주사업  1999-08-11         12월
# 2                                             지주회사  2014-05-19         12월
# 3                                          체인화 편의점  2017-12-08         12월
# ...
