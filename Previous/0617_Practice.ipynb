# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
movie_url= 'https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189150&target=after'
page = urlopen(movie_url)
soup = BeautifulSoup(page, "html.parser")
comment_all = soup.find_all('td', class_='title')
list(comment_all)
# Out:
# [<td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=189150">분노의 질주: 더 얼티메이트</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:40%">별점 - 총 10점 중</span></span><em>4</em>
#  </div>
#  <br/>연출, 영상미, 스토리 모두 기대이하입니다. 액션만 볼만 합니다.
#
#
#
#
#
#
#  				<a class="report" href="#" onclick="report('gtee****', 'aC2lzPuUFyIahTrGwaGexIxLZrYhevsPfyZPYWLj1Bo=', '연출, 영상미, 스토리 모두 기대이하입니다. 액션만 볼만 합니다.', '17555732', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>
#  </td>,
#  <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=189150">분노의 질주: 더 얼티메이트</a>
#  <div class="list_netizen_score">
#  <span class="st_off"><span class="st_on" style="width:20%">별점 - 총 10점 중</span></span><em>2</em>
#  </div>
#  <br/>그냥 막장 스토리와 비슷한 느낌..  아무리 영화라지만 인간들의 영화를 이런 공감이라고는 전혀할 수 없는 영화를 만들다니..차라리 슈퍼히어로물이라면 이해가가겠다.. 분노의질주 시리즈 중 최악..
#
#
#
#
#
#
# ...

# %%
print(comment_all[1].prettify())
# Out:
# <td class="title">
#  <a class="movie color_b" href="/movie/bi/mi/basic.nhn?code=189150">
#   분노의 질주: 더 얼티메이트
#  </a>
#  <div class="list_netizen_score">
#   <span class="st_off">
#    <span class="st_on" style="width:20%">
#     별점 - 총 10점 중
#    </span>
#   </span>
#   <em>
#    2
#   </em>
#  </div>
#  <br/>
#  그냥 막장 스토리와 비슷한 느낌..  아무리 영화라지만 인간들의 영화를 이런 공감이라고는 전혀할 수 없는 영화를 만들다니..차라리 슈퍼히어로물이라면 이해가가겠다.. 분노의질주 시리즈 중 최악..
#  <a class="report" href="#" onclick="report('song****', 'MV3Z0eabF1593VMWnExGfwLrj5MvLTvXS5EKQ+M+RUM=', '그냥 막장 스토리와 비슷한 느낌..  아무리 영화라지만 인간들의 영화를 이런 공감이라고는 전혀할 수 없는 영화를 만들다니..차라리 슈퍼히어로물이라면 이해가가겠다.. 분노의질주 시리즈 중 최악..', '17555674', 'point_after');" style="color:#8F8F8F" title="새 창">
#   신고
#  </a>
# </td>

# %%
com_one = list(comment_all[1].children)[6].strip()

# %%
comments =[]
for i in range(1,51):
    url = movie_url + str(i)
    page = urlopen(url)
    soup = BeautifulSoup(page, 'html.parser')
    
    comment_all = soup.find_all('td', class_='title')
    
    for one in comment_all:
        one_com = list(one.children)[6].strip()
        print(one_com)
        comments.append(one_com)
# Out:
# 애정담아 7줍니다..그냥 읭스럽고 너무너무 좋게만 풀려가는게 끝물인것같기도하고..그래도 분노의질주 사랑해요.. 분노의질주 특유의 차 때려뿌시는 것만 봐줄만했음요빌런도 너무 약하고; 뻔한스토리에... 영웅물보는줄
# 자동차터지는맛에봄
# 연출, 영상미, 스토리 모두 기대이하입니다. 액션만 볼만 합니다.
# 그냥 막장 스토리와 비슷한 느낌..  아무리 영화라지만 인간들의 영화를 이런 공감이라고는 전혀할 수 없는 영화를 만들다니..차라리 슈퍼히어로물이라면 이해가가겠다.. 분노의질주 시리즈 중 최악..
# 분노의질주 팬으로서 영화보고 집에 가는 길.. 분노의 질주를 했다
# 1편부터 지금까지 다봤는데 시리즈중 가장 별로 점점 액션 오바 넘치는건 알겠지만 너무 심함 다음편 기대가 안되네요
# 개봉일에  보고 생각나서 네이버 들어왔는데 성강 배우 그리팅 영상 보고 빵터짐 ㅋㅋㅋㅋ 강성홉니다~!ㅋㅋㅋㅋ 영화 두번 봤는데 또 보고싶다.
# 역시 영화는 뭐니뭐니 해두 극장에서 딱 봐야 제대로 즐기지
# 지금까지 분노의 질주 시리즈 다봤는데 이번작은 액션이 진짜 너무 뇌절인듯 그냥 머리비우고 보기는 ㄱㅊ음
# 역대급1OO영화같아 한국식 즙짜기 오지게 느껴진다 나쁜거만 배워 적용한듯
# 애정담아 7줍니다..그냥 읭스럽고 너무너무 좋게만 풀려가는게 끝물인것같기도하고..그래도 분노의질주 사랑해요.. 분노의질주 특유의 차 때려뿌시는 것만 봐줄만했음요빌런도 너무 약하고; 뻔한스토리에... 영웅물보는줄
# 자동차터지는맛에봄
# 연출, 영상미, 스토리 모두 기대이하입니다. 액션만 볼만 합니다.
# 그냥 막장 스토리와 비슷한 느낌..  아무리 영화라지만 인간들의 영화를 이런 공감이라고는 전혀할 수 없는 영화를 만들다니..차라리 슈퍼히어로물이라면 이해가가겠다.. 분노의질주 시리즈 중 최악..
# 분노의질주 팬으로서 영화보고 집에 가는 길.. 분노의 질주를 했다
# 1편부터 지금까지 다봤는데 시리즈중 가장 별로 점점 액션 오바 넘치는건 알겠지만 너무 심함 다음편 기대가 안되네요
# ...

# %%
import pandas as pd
import os

# %%
dict_doc = {"text":comments}
doc = pd.DataFrame(dict_doc)
doc.to_csv("분노의질주_더얼티메이트리뷰_0617.csv", index=False)

os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '0616 BeautifulSoup.ipynb',
#  '0616_practice.ipynb',
#  '0617_NaverStock.ipynb',
#  '0617_Practice.ipynb',
#  '0617_SpiderMovieReview.ipynb',
#  '0617_WordCloud.ipynb',
#  'data',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  '분노의질주_더얼티메이트리뷰_0617.csv',
#  '스파이더맨리뷰_0617.csv',
#  '회사명과 웹사이트.csv',
#  '회사명과 웹사이트.xlsx']

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
file = open('분노의질주_더얼티메이트리뷰_0617.csv', encoding='utf-8')
text = file.read()
file.close()

# %%
from matplotlib import rc
import numpy as np
rc('font', family='NanumGothic')

# %%
max_mask = np.array(Image.open("maxresdefault.png"))
wcloud = WordCloud('./data/D2Coding.ttf',stopwords=["끝물","읭스럽고","그냥","영화","너무너무"],max_words=50000
                   , relative_scaling = 0.1, mask = max_mask,max_font_size=300).generate(text)
# wcloud = WordCloud('./data/HYDNKB',max_words=1000, relative_scaling = 0.5).generate(text)

import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.imshow(wcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 859.5, 324.5, -0.5)
